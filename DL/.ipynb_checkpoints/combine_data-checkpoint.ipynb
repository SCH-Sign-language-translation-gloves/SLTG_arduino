# %%
import pandas as pd
import numpy as np
import matplotlib as mp
import seaborn as sb
import matplotlib.pyplot as plt
import random

# %%
list = {'ㄱ':0,'ㄴ':1,'ㄷ':2,'ㄹ':3,'ㅁ':4,'ㅂ':5,'ㅅ':6,'ㅇ':7,'ㅈ':8,'ㅊ':9,'ㅋ':10,'ㅌ':11,'ㅍ':12,'ㅎ':13,
        'ㅏ':14,'ㅑ':15,'ㅓ':16,'ㅕ':17,'ㅗ':18,'ㅛ':19,'ㅜ':20,'ㅠ':21,'ㅡ':22,'ㅣ':23,'ㅐ':24,'ㅒ':25,'ㅔ':26,'ㅖ':27,'ㅢ':28,'ㅟ':29}

# %%
list
# Out:
# {'ㄱ': 0,
#  'ㄴ': 1,
#  'ㄷ': 2,
#  'ㄹ': 3,
#  'ㅁ': 4,
#  'ㅂ': 5,
#  'ㅅ': 6,
#  'ㅇ': 7,
#  'ㅈ': 8,
#  'ㅊ': 9,
#  'ㅋ': 10,
#  'ㅌ': 11,
#  'ㅍ': 12,
#  'ㅎ': 13,
#  'ㅏ': 14,
#  'ㅑ': 15,
#  'ㅓ': 16,
#  'ㅕ': 17,
#  'ㅗ': 18,
#  'ㅛ': 19,
#  'ㅜ': 20,
#  'ㅠ': 21,
#  'ㅡ': 22,
#  'ㅣ': 23,
#  'ㅐ': 24,
#  'ㅒ': 25,
#  'ㅔ': 26,
#  'ㅖ': 27,
#  'ㅢ': 28,
#  'ㅟ': 29}

# %%
a = pd.read_csv('../data/User/모음/jh/ㅟ.csv')
b = pd.read_csv('../data/User/모음/nh/ㅟ.csv')
c = pd.read_csv('../data/User/모음/yj/ㅟ.csv')
d = pd.read_csv('../data/User/모음/jy/ㅟ.csv')

# %%
a.columns = ["aX", "aY", "aZ", "gX","gY","gZ",'little','ring','middle','index','thumb']
b.columns = ["aX", "aY", "aZ", "gX","gY","gZ",'little','ring','middle','index','thumb']
c.columns = ["aX", "aY", "aZ", "gX","gY","gZ",'little','ring','middle','index','thumb']
d.columns = ["aX", "aY", "aZ", "gX","gY","gZ",'little','ring','middle','index','thumb']

# %%
one_data = pd.concat([a,b,c,d],sort=False,ignore_index = True)

# %%
one_data
# Out:
#         aX    aY    aZ    gX    gY    gZ  little  ring  middle  index  thumb
# 0     0.12  0.81  0.55  0.49 -3.48 -3.60     359   260     219    459    325
# 1     0.11  0.83  0.55 -0.73 -2.01 -3.30     362   263     219    460    323
# 2     0.10  0.84  0.56  0.37 -2.62 -0.79     360   265     218    460    324
# 3     0.10  0.84  0.56  1.46 -5.13 -1.71     359   280     222    459    325
# 4     0.11  0.83  0.56 -3.23 -5.31 -2.93     357   264     219    455    326
# ...    ...   ...   ...   ...   ...   ...     ...   ...     ...    ...    ...
# 2018  0.38  0.79  0.47  1.16 -0.73 -2.99     412   397     265    448    358
# 2019  0.37  0.81  0.49  9.70 -8.61  9.83     410   397     268    447    360
# 2020  0.42  0.79  0.43  3.11 -2.32 -2.20     408   396     267    450    359
# 2021  0.42  0.80  0.44  1.65 -3.36 -2.75     410   401     264    454    359
# 2022  0.41  0.79  0.44 -1.46 -2.01 -3.85     408   395     267    448    361
#
# [2023 rows x 11 columns]

# %%
one_data.insert(11,'number',29)

# %%
one_data
# Out:
#         aX    aY    aZ    gX    gY    gZ  little  ring  middle  index  thumb  \
# 0     0.12  0.81  0.55  0.49 -3.48 -3.60     359   260     219    459    325
# 1     0.11  0.83  0.55 -0.73 -2.01 -3.30     362   263     219    460    323
# 2     0.10  0.84  0.56  0.37 -2.62 -0.79     360   265     218    460    324
# 3     0.10  0.84  0.56  1.46 -5.13 -1.71     359   280     222    459    325
# 4     0.11  0.83  0.56 -3.23 -5.31 -2.93     357   264     219    455    326
# ...    ...   ...   ...   ...   ...   ...     ...   ...     ...    ...    ...
# 2018  0.38  0.79  0.47  1.16 -0.73 -2.99     412   397     265    448    358
# 2019  0.37  0.81  0.49  9.70 -8.61  9.83     410   397     268    447    360
# 2020  0.42  0.79  0.43  3.11 -2.32 -2.20     408   396     267    450    359
# 2021  0.42  0.80  0.44  1.65 -3.36 -2.75     410   401     264    454    359
# 2022  0.41  0.79  0.44 -1.46 -2.01 -3.85     408   395     267    448    361
#
#       number
# 0         29
# 1         29
# 2         29
# 3         29
# 4         29
# ...      ...
# 2018      29
# 2019      29
# 2020      29
# 2021      29
# 2022      29
#
# [2023 rows x 12 columns]

# %%
one_data.to_csv('../data/data_set/ㅟ.csv')

# %%
one_data.duplicated().sum()
# Out:
# 0

# %%
import os
import glob
import pandas as pd

os.chdir('../data/data_set')
extension = 'csv' #csv로 파일 확장자 지정 
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ]) #지정한 파일 경로에 있는 모든 파일 불러오기
#export to csv
combined_csv.to_csv( "combined_csv.csv", index=False, encoding='cp949')

# %%
import os
os.listdir('../data/data_set')
# Out:
# ['ㄱ.csv',
#  'ㄴ.csv',
#  'ㄷ.csv',
#  'ㄹ.csv',
#  'ㅁ.csv',
#  'ㅂ.csv',
#  'ㅅ.csv',
#  'ㅇ.csv',
#  'ㅈ.csv',
#  'ㅊ.csv',
#  'ㅋ.csv',
#  'ㅌ.csv',
#  'ㅍ.csv',
#  'ㅎ.csv',
#  'ㅏ.csv',
#  'ㅐ.csv',
#  'ㅑ.csv',
#  'ㅒ.csv',
#  'ㅓ.csv',
#  'ㅔ.csv',
#  'ㅕ.csv',
#  'ㅖ.csv',
#  'ㅗ.csv',
#  'ㅛ.csv',
#  'ㅜ.csv',
#  'ㅟ.csv',
#  'ㅠ.csv',
#  'ㅡ.csv',
#  'ㅢ.csv',
#  'ㅣ.csv']

# %%
nums = ['ㄱ','ㄴ','ㄷ','ㄹ','ㅁ','ㅂ','ㅅ','ㅇ','ㅈ','ㅊ','ㅋ','ㅌ','ㅍ','ㅎ','ㅏ','ㅑ','ㅓ','ㅕ','ㅗ','ㅛ','ㅜ','ㅠ','ㅡ','ㅣ','ㅐ','ㅒ','ㅔ','ㅖ','ㅢ','ㅟ']
forders = os.listdir('../data/data_set')
all_data = pd.DataFrame()

for files in forders:
    path = '../data/data_set/%s.csv'%files
    df = pd.read_csv(path,engine='python', encoding='cp949')
    all_data = pd.concat([all_data, df])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-292-47e1f7065e86> in <module>
#       5 for files in forders:
#       6     path = '../data/data_set/%s.csv'%files
# ----> 7     df = pd.read_csv(path,engine='python', encoding='cp949')
#       8     all_data = pd.concat([all_data, df])
#
# E:\Python\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# E:\Python\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# E:\Python\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# E:\Python\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# E:\Python\lib\site-packages\pandas\io\parsers.py in __init__(self, f, **kwds)
#    2291             self.data = cast(Iterator[str], f)
#    2292         else:
# -> 2293             self._open_handles(f, kwds)
#    2294             assert self.handles is not None
#    2295             assert hasattr(self.handles.handle, "readline")
#
# E:\Python\lib\site-packages\pandas\io\parsers.py in _open_handles(self, src, kwds)
#    1360         Let the readers open IOHanldes after they are done with their potential raises.
#    1361         """
# -> 1362         self.handles = get_handle(
#    1363             src,
#    1364             "r",
#
# E:\Python\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/data_set/ㄱ.csv.csv'
