# %%
import numpy as np
import pandas as pd

# %%
nums=['ㄱ','ㄴ','ㄷ','ㄹ','ㅁ_','ㅂ','ㅅ_','ㅇ','ㅈ','ㅊ','ㅋ_','ㅌ','ㅍ_','ㅎ']

for num in nums:
    path = './right_data/자음_v2/%s.csv'%num
    print()
    print(num)
    num = pd.read_csv(path, engine='python', encoding='cp949')
    num.columns =["X", "Y", "Z", "gX","gY","gZ","f1","f2","f3","f4","f5"]
    data = num.describe()
    
    print(data)
#print(num)
# Out:
# ㄱ
#                 X           Y           Z          gX          gY          gZ  \
# count  599.000000  599.000000  599.000000  599.000000  599.000000  599.000000
# mean     0.670534    0.634791    0.407863    1.827078   -3.602287   -2.350768
# std      0.082056    0.069956    0.054617    2.516462    2.430599    2.248439
# min      0.530000    0.410000    0.260000  -32.040000  -32.170000  -11.410000
# 25%      0.600000    0.610000    0.370000    0.850000   -4.270000   -3.230000
# 50%      0.670000    0.640000    0.410000    1.950000   -3.540000   -2.380000
# 75%      0.720000    0.690000    0.450000    2.960000   -2.870000   -1.650000
# max      0.880000    0.760000    0.540000   11.230000   21.360000   13.670000
#
#                f1          f2          f3          f4          f5
# count  599.000000  599.000000  599.000000  599.000000  599.000000
# mean   319.048414  327.849750  223.662771  438.916528  493.225376
# ...

# %%
nums_vowel=['ㅏ','ㅐ','ㅑ','ㅒ','ㅓ','ㅔ','ㅕ','ㅖ','ㅗ','ㅚ','ㅛ','ㅜ','ㅟ','ㅠ','ㅡ','ㅣ']

for num_vowel in nums_vowel:
    path = './right_data/모음_v2/%s.csv'%num_vowel
    print()
    print(num_vowel)
    num_vowel = pd.read_csv(path, engine='python', encoding='cp949')
    num_vowel.columns =["X", "Y", "Z", "gX","gY","gZ","f1","f2","f3","f4","f5"]
    data = num_vowel.describe()
    
    print(data)
#print(num)
# Out:
# ㅏ
#                 X           Y          Z          gX          gY          gZ  \
# count  500.000000  500.000000  500.00000  500.000000  500.000000  500.000000
# mean     0.281820   -0.941920   -0.01198    2.025960   -3.539180   -2.435980
# std      0.061482    0.027309    0.13172    3.165408    2.819162    2.358427
# min      0.140000   -1.020000   -0.30000  -19.350000  -23.320000  -12.760000
# 25%      0.240000   -0.960000   -0.09000    0.670000   -4.270000   -3.230000
# 50%      0.270000   -0.950000   -0.02500    2.080000   -3.600000   -2.440000
# 75%      0.310000   -0.930000    0.10250    3.315000   -3.050000   -1.770000
# max      0.510000   -0.830000    0.26000   16.050000   22.830000   12.630000
#
#                f1          f2          f3          f4          f5
# count  500.000000  500.000000  500.000000  500.000000  500.000000
# mean   345.644000  325.840000  196.380000  437.564000  426.978000
# std     13.252945   11.167445    5.182404   19.672415   10.562037
# ...
